# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext lab_black

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from random import randrange
import tensorflow as tf
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.metrics import classification_report

from utils.utility_functions import listdir_nohidden_sorted as lsdir
from vision.vision_utils.video_seq_generator import VideoSeqGenerator

# %% [markdown]
# ### Paths

# %%
MED_FALL = "/home/jovyan/work/MED_Fall"
GROUND_TRUTH_PATH = f"{MED_FALL}/vision/vision_dataset/ground_truth_new"
FRAMES_PATH = f"{MED_FALL}/vision/vision_dataset/extracted_frames"

# %%
SEQ_LEN: int = 16
STRIDE: int = 8
BATCH_SIZE: int = 16
INPUT_SHAPE: tuple[int, int, int] = (112, 112, 3)

# %% [markdown]
# ### Hyperparameters

# %% [markdown]
# ### Utility Functions

# %%
def get_cam(name: str) -> int:
    """
    Extract cam number from each video frame name
    ------

    arguments:
        - name: string containing the frame name. Examle: 'Actor_1_bed_cam_1_0000'

    outputs:
        - cam_number: integer containg the cam number of the provided frame name.
                    Example: if name is 'Actor_1_bed_cam_1_0000', cam_number is: 1.
    """

    start = name.find("cam_")
    ind = start + 4
    cam_number = name[ind]
    return int(cam_number)


def show_frames_series(
    frames_series: np.array, title: str, figsize: tuple[int, int] = (20, 20), nrows=5
):
    """
    plot a series of SEQ_LEN frames with respective labels as titles.
    --------

    arguments:
        - frames_series: np.array containg SEQ_LEN images.
        - title: strcontainging the label of the series of frame. The label is calculated as the mode (most frequent label) of the single frames' labels.
        - fig_size: Optional. Tuple of two integers containing the figure dimensions for the plot. Default is (20, 20).

    """
    rows = nrows

    fig = plt.figure(figsize=figsize)
    for n, image in enumerate(frames_series):
        a = fig.add_subplot(rows, int(len(frames_series) / float(rows)), n + 1)

        plt.imshow(image)
        plt.axis("off")
    fig.suptitle(title)
    plt.show()

# %% [markdown]
# ## Load Dataset

# %%
# Load all csv files (one per actor). Each file contains frames names and respective labels.
dfs = []
for file in lsdir(GROUND_TRUTH_PATH):
    df = pd.read_csv(file)
    dfs.append(df)
# concatenate all csv files in one pandas DF
dataset = pd.concat(dfs, ignore_index=True, axis=0)
dataset = dataset.iloc[:, 2:]
dataset
# Out:
#                 micro_labels macro_labels            ar_labels  \
# 0                  lie_still   lying_down  actor_repositioning
# 1                  lie_still   lying_down  actor_repositioning
# 2                  lie_still   lying_down  actor_repositioning
# 3                  lie_still   lying_down  actor_repositioning
# 4                  lie_still   lying_down  actor_repositioning
# ...                      ...          ...                  ...
# 1182295  stand_up_from_floor          adl  actor_repositioning
# 1182296  stand_up_from_floor          adl  actor_repositioning
# 1182297  stand_up_from_floor          adl  actor_repositioning
# 1182298  stand_up_from_floor          adl  actor_repositioning
# 1182299  stand_up_from_floor          adl  actor_repositioning
#
#                                frame_name
# 0                  actor_1_bed_cam_1_0000
# 1                  actor_1_bed_cam_1_0001
# 2                  actor_1_bed_cam_1_0002
# 3                  actor_1_bed_cam_1_0003
# 4                  actor_1_bed_cam_1_0004
# ...                                   ...
# 1182295  actor_4_chair_full_ph_cam_7_4615
# 1182296  actor_4_chair_full_ph_cam_7_4616
# 1182297  actor_4_chair_full_ph_cam_7_4617
# 1182298  actor_4_chair_full_ph_cam_7_4618
# 1182299  actor_4_chair_full_ph_cam_7_4619
#
# [1182300 rows x 4 columns]

# %%
# Select only "on_air" frames (where actors are performing sequences)
dataset_onair = dataset.loc[dataset["ar_labels"] == "on_air"].copy()
dataset_onair
# Out:
#               micro_labels macro_labels ar_labels  \
# 206      sit_up_from_lying          adl    on_air
# 207      sit_up_from_lying          adl    on_air
# 208      sit_up_from_lying          adl    on_air
# 209      sit_up_from_lying          adl    on_air
# 210      sit_up_from_lying          adl    on_air
# ...                    ...          ...       ...
# 1182213     crouched_still      falling    on_air
# 1182214     crouched_still      falling    on_air
# 1182215     crouched_still      falling    on_air
# 1182216     crouched_still      falling    on_air
# 1182217     crouched_still      falling    on_air
#
#                                frame_name
# 206                actor_1_bed_cam_1_0206
# 207                actor_1_bed_cam_1_0207
# 208                actor_1_bed_cam_1_0208
# 209                actor_1_bed_cam_1_0209
# 210                actor_1_bed_cam_1_0210
# ...                                   ...
# 1182213  actor_4_chair_full_ph_cam_7_4533
# 1182214  actor_4_chair_full_ph_cam_7_4534
# 1182215  actor_4_chair_full_ph_cam_7_4535
# 1182216  actor_4_chair_full_ph_cam_7_4536
# 1182217  actor_4_chair_full_ph_cam_7_4537
#
# [386106 rows x 4 columns]

# %%
# check on_air dataset samples per class
dataset_onair["macro_labels"].value_counts()
# Out:
# adl           269836
# falling        88312
# lying_down     27958
# Name: macro_labels, dtype: int64

# %%
# instantiate and fit a OneHotEncoder for the macro classes (adl, fall, lie_down)
le = LabelBinarizer()
le.fit(dataset_onair["macro_labels"])
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
le_name_mapping
# Out:
# {'adl': array([1, 0, 0]),
#  'falling': array([0, 1, 0]),
#  'lying_down': array([0, 0, 1])}

# %% [markdown]
# ## Use actor 4 as val set

# %%
actor_4 = dataset_onair.loc[dataset_onair["frame_name"].str.contains("actor_4")].copy()
actor_4
# Out:
#               micro_labels macro_labels ar_labels  \
# 1014006  sit_up_from_lying          adl    on_air
# 1014007  sit_up_from_lying          adl    on_air
# 1014008  sit_up_from_lying          adl    on_air
# 1014009  sit_up_from_lying          adl    on_air
# 1014010  sit_up_from_lying          adl    on_air
# ...                    ...          ...       ...
# 1182213     crouched_still      falling    on_air
# 1182214     crouched_still      falling    on_air
# 1182215     crouched_still      falling    on_air
# 1182216     crouched_still      falling    on_air
# 1182217     crouched_still      falling    on_air
#
#                                frame_name  cam        actor_seq
# 1014006            actor_4_bed_cam_1_0126    1            4_bed
# 1014007            actor_4_bed_cam_1_0127    1            4_bed
# 1014008            actor_4_bed_cam_1_0128    1            4_bed
# 1014009            actor_4_bed_cam_1_0129    1            4_bed
# 1014010            actor_4_bed_cam_1_0130    1            4_bed
# ...                                   ...  ...              ...
# 1182213  actor_4_chair_full_ph_cam_7_4533    7  4_chair_full_ph
# 1182214  actor_4_chair_full_ph_cam_7_4534    7  4_chair_full_ph
# 1182215  actor_4_chair_full_ph_cam_7_4535    7  4_chair_full_ph
# 1182216  actor_4_chair_full_ph_cam_7_4536    7  4_chair_full_ph
# 1182217  actor_4_chair_full_ph_cam_7_4537    7  4_chair_full_ph
#
# [39368 rows x 6 columns]

# %%
train_set = dataset_onair.drop(actor_4.index)
train_set
# Out:
#                   micro_labels macro_labels ar_labels  \
# 206          sit_up_from_lying          adl    on_air
# 207          sit_up_from_lying          adl    on_air
# 208          sit_up_from_lying          adl    on_air
# 209          sit_up_from_lying          adl    on_air
# 210          sit_up_from_lying          adl    on_air
# ...                        ...          ...       ...
# 1013767  lie_down_on_the_floor   lying_down    on_air
# 1013768  lie_down_on_the_floor   lying_down    on_air
# 1013769  lie_down_on_the_floor   lying_down    on_air
# 1013770  lie_down_on_the_floor   lying_down    on_air
# 1013771  lie_down_on_the_floor   lying_down    on_air
#
#                                     frame_name  cam             actor_seq
# 206                     actor_1_bed_cam_1_0206    1                 1_bed
# 207                     actor_1_bed_cam_1_0207    1                 1_bed
# 208                     actor_1_bed_cam_1_0208    1                 1_bed
# 209                     actor_1_bed_cam_1_0209    1                 1_bed
# 210                     actor_1_bed_cam_1_0210    1                 1_bed
# ...                                        ...  ...                   ...
# 1013767  actor_3_walk_stick_full_ph_cam_7_5767    7  3_walk_stick_full_ph
# 1013768  actor_3_walk_stick_full_ph_cam_7_5768    7  3_walk_stick_full_ph
# 1013769  actor_3_walk_stick_full_ph_cam_7_5769    7  3_walk_stick_full_ph
# 1013770  actor_3_walk_stick_full_ph_cam_7_5770    7  3_walk_stick_full_ph
# 1013771  actor_3_walk_stick_full_ph_cam_7_5771    7  3_walk_stick_full_ph
#
# [346738 rows x 6 columns]

# %%
train_set["macro_labels"].value_counts()
# Out:
# adl           244132
# falling        75320
# lying_down     27286
# Name: macro_labels, dtype: int64

# %%
val_set = actor_4
val_set
# Out:
#               micro_labels macro_labels ar_labels  \
# 1014006  sit_up_from_lying          adl    on_air
# 1014007  sit_up_from_lying          adl    on_air
# 1014008  sit_up_from_lying          adl    on_air
# 1014009  sit_up_from_lying          adl    on_air
# 1014010  sit_up_from_lying          adl    on_air
# ...                    ...          ...       ...
# 1182213     crouched_still      falling    on_air
# 1182214     crouched_still      falling    on_air
# 1182215     crouched_still      falling    on_air
# 1182216     crouched_still      falling    on_air
# 1182217     crouched_still      falling    on_air
#
#                                frame_name  cam        actor_seq
# 1014006            actor_4_bed_cam_1_0126    1            4_bed
# 1014007            actor_4_bed_cam_1_0127    1            4_bed
# 1014008            actor_4_bed_cam_1_0128    1            4_bed
# 1014009            actor_4_bed_cam_1_0129    1            4_bed
# 1014010            actor_4_bed_cam_1_0130    1            4_bed
# ...                                   ...  ...              ...
# 1182213  actor_4_chair_full_ph_cam_7_4533    7  4_chair_full_ph
# 1182214  actor_4_chair_full_ph_cam_7_4534    7  4_chair_full_ph
# 1182215  actor_4_chair_full_ph_cam_7_4535    7  4_chair_full_ph
# 1182216  actor_4_chair_full_ph_cam_7_4536    7  4_chair_full_ph
# 1182217  actor_4_chair_full_ph_cam_7_4537    7  4_chair_full_ph
#
# [39368 rows x 6 columns]

# %%
val_set["macro_labels"].value_counts()
# Out:
# adl           25704
# falling       12992
# lying_down      672
# Name: macro_labels, dtype: int64

# %% [markdown]
# ## Balance dataset

# %%
dataset_balanced = dataset_onair.copy()  # make a copy of on_air dataset

counts = dataset_balanced["macro_labels"].value_counts()  # count samples per class
minority_class_samples = counts[-1]  # store minority class samples

# select adl samples
adl_samples = dataset_onair.loc[dataset["macro_labels"] == "adl"]

# select fall samples
fall_samples = dataset_onair.loc[dataset["macro_labels"] == "falling"]

## subsample

# count exceeding adl samples wrt minority_class_samples
adl_todrop_ind = len(adl_samples) - minority_class_samples
# count exceeding fall samples wrt minority_class_samples
fall_todrop_ind = len(fall_samples) - minority_class_samples

# select indices to drop from adl subset
adl_samples_to_drop = adl_samples.iloc[-adl_todrop_ind:]

# select indices to drop from fall subset
fall_samples_to_drop = fall_samples.iloc[-fall_todrop_ind:]

# actually drop exceeding adl samples
dataset_balanced.drop(adl_samples_to_drop.index, axis=0, inplace=True)

# actually drop exceeding fall samples
dataset_balanced.drop(fall_samples_to_drop.index, axis=0, inplace=True)

# count samples per class of the balanced dataset
dataset_balanced["macro_labels"].value_counts()
# Out:
# adl           27958
# falling       27958
# lying_down    27958
# Name: macro_labels, dtype: int64

# %% [markdown]
# ## Train test split

# %%
# Take first 90% of the balanced dataset as train data and remaining 10% as val data.
# NB: no shuffling is applied as frames must be consecutive to later split them in time-series.
split_ratio = 0.9
split = int(len(dataset_balanced) * split_ratio)
train_set = dataset_balanced.iloc[:split, :].copy()
val_set = dataset_balanced.iloc[split:, :].copy()

minority_val_samples = val_set["macro_labels"].value_counts()[0]

# show samples per class in each set
print(train_set["macro_labels"].value_counts())
print(val_set["macro_labels"].value_counts())
# Out:
# adl           27958
# falling       27958
# lying_down    19570
# Name: macro_labels, dtype: int64
# lying_down    8388
# Name: macro_labels, dtype: int64

# %%
# show train set
train_set
# Out:
#                  micro_labels macro_labels ar_labels  \
# 206         sit_up_from_lying          adl    on_air
# 207         sit_up_from_lying          adl    on_air
# 208         sit_up_from_lying          adl    on_air
# 209         sit_up_from_lying          adl    on_air
# 210         sit_up_from_lying          adl    on_air
# ...                       ...          ...       ...
# 548212  lie_down_on_the_floor   lying_down    on_air
# 548213  lie_down_on_the_floor   lying_down    on_air
# 548214  lie_down_on_the_floor   lying_down    on_air
# 548215  lie_down_on_the_floor   lying_down    on_air
# 548216  lie_down_on_the_floor   lying_down    on_air
#
#                             frame_name  cam      actor_seq
# 206             actor_1_bed_cam_1_0206    1          1_bed
# 207             actor_1_bed_cam_1_0207    1          1_bed
# 208             actor_1_bed_cam_1_0208    1          1_bed
# 209             actor_1_bed_cam_1_0209    1          1_bed
# 210             actor_1_bed_cam_1_0210    1          1_bed
# ...                                ...  ...            ...
# 548212  actor_2_bed_rolling_cam_3_1552    3  2_bed_rolling
# 548213  actor_2_bed_rolling_cam_3_1553    3  2_bed_rolling
# 548214  actor_2_bed_rolling_cam_3_1554    3  2_bed_rolling
# 548215  actor_2_bed_rolling_cam_3_1555    3  2_bed_rolling
# 548216  actor_2_bed_rolling_cam_3_1556    3  2_bed_rolling
#
# [75486 rows x 6 columns]

# %%
val_set_copy = pd.concat(
    [
        val_set,
        adl_samples_to_drop.iloc[0:minority_val_samples, :],
        fall_samples_to_drop.iloc[0:minority_val_samples, :],
    ],
    axis=0,
)
val_set_copy
# Out:
#                  micro_labels macro_labels ar_labels  \
# 548217  lie_down_on_the_floor   lying_down    on_air
# 548218  lie_down_on_the_floor   lying_down    on_air
# 548219  lie_down_on_the_floor   lying_down    on_air
# 548220  lie_down_on_the_floor   lying_down    on_air
# 548221  lie_down_on_the_floor   lying_down    on_air
# ...                       ...          ...       ...
# 490071           fall_frontal      falling    on_air
# 490072           fall_frontal      falling    on_air
# 490073           fall_frontal      falling    on_air
# 490074           fall_frontal      falling    on_air
# 490075           fall_frontal      falling    on_air
#
#                             frame_name  cam      actor_seq
# 548217  actor_2_bed_rolling_cam_3_1557  3.0  2_bed_rolling
# 548218  actor_2_bed_rolling_cam_3_1558  3.0  2_bed_rolling
# 548219  actor_2_bed_rolling_cam_3_1559  3.0  2_bed_rolling
# 548220  actor_2_bed_rolling_cam_3_1560  3.0  2_bed_rolling
# 548221  actor_2_bed_rolling_cam_3_1561  3.0  2_bed_rolling
# ...                                ...  ...            ...
# 490071   actor_2_bed_armour_cam_7_0951  NaN            NaN
# 490072   actor_2_bed_armour_cam_7_0952  NaN            NaN
# 490073   actor_2_bed_armour_cam_7_0953  NaN            NaN
# 490074   actor_2_bed_armour_cam_7_0954  NaN            NaN
# 490075   actor_2_bed_armour_cam_7_0955  NaN            NaN
#
# [25164 rows x 6 columns]

# %%
val_set_copy["macro_labels"].value_counts()
# Out:
# lying_down    8388
# adl           8388
# falling       8388
# Name: macro_labels, dtype: int64

# %% [markdown]
# ## Instantiate train and val generators
# ### VideoSeqGenerator works as follows:
# - takes a dataframe containing the frame names and the corresponding labels as input
# - splits the dataframe in time series of length SEQ_LEN
# - for each series:
#     - loads a batch made of BATCH_SIZE * SEQ_LEN frames into a tensor called "X"
#     - for each window (time-series) of the batch caluculates the mode of the frames, applies OneHotEncoding and stores the encoded windows' labels in a tensor called "y".
#     - returns X,y.
#       X has shape (BATCH_SIZE, SEQ_LEN, IMAGE_SIZE), for example (32, 20, 224, 224, 3)
#       y has shape (BATCH_SIZE, 3),  where 3 derives from the one hot encoding of the 3 classes (adl, fall, lie_down)

# %%
# instantiating train generator. For this test there will be only one generator which takes the whole dataset as input
train_gen = VideoSeqGenerator(
    frames_path=FRAMES_PATH,
    df=train_set,
    seq_len=SEQ_LEN,
    stride=STRIDE,
    batch_size=BATCH_SIZE,
    label_encoder=le,
    input_shape=INPUT_SHAPE,
)
# Out:
# (112, 112, 3)
# <class 'tuple'>

# %%
val_gen = VideoSeqGenerator(
    frames_path=FRAMES_PATH,
    df=val_set,
    seq_len=SEQ_LEN,
    batch_size=BATCH_SIZE,
    stride=STRIDE,
    label_encoder=le,
    input_shape=INPUT_SHAPE,
)
# Out:
# (112, 112, 3)
# <class 'tuple'>

# %%
train_gen.s_s[-1]
# Out:
# 10824

# %%
len(val_gen.windows_labels)
# Out:
# 2460

# %%
pd.Series(val_gen.windows_labels).value_counts()
# Out:
# adl           1825
# falling        584
# lying_down      51
# dtype: int64

# %%
len(train_gen.s_s)
# Out:
# 1354

# %%
train_gen.df
# Out:
#               micro_labels macro_labels ar_labels  \
# 206      sit_up_from_lying          adl    on_air
# 207      sit_up_from_lying          adl    on_air
# 208      sit_up_from_lying          adl    on_air
# 209      sit_up_from_lying          adl    on_air
# 210      sit_up_from_lying          adl    on_air
# ...                    ...          ...       ...
# 1182213     crouched_still      falling    on_air
# 1182214     crouched_still      falling    on_air
# 1182215     crouched_still      falling    on_air
# 1182216     crouched_still      falling    on_air
# 1182217     crouched_still      falling    on_air
#
#                                frame_name  cam        actor_seq
# 206                actor_1_bed_cam_1_0206    1            1_bed
# 207                actor_1_bed_cam_1_0207    1            1_bed
# 208                actor_1_bed_cam_1_0208    1            1_bed
# 209                actor_1_bed_cam_1_0209    1            1_bed
# 210                actor_1_bed_cam_1_0210    1            1_bed
# ...                                   ...  ...              ...
# 1182213  actor_4_chair_full_ph_cam_7_4533    7  4_chair_full_ph
# 1182214  actor_4_chair_full_ph_cam_7_4534    7  4_chair_full_ph
# 1182215  actor_4_chair_full_ph_cam_7_4535    7  4_chair_full_ph
# 1182216  actor_4_chair_full_ph_cam_7_4536    7  4_chair_full_ph
# 1182217  actor_4_chair_full_ph_cam_7_4537    7  4_chair_full_ph
#
# [386106 rows x 6 columns]

# %%
print(len(train_gen.windows_labels))
pd.Series(train_gen.windows_labels).value_counts()
# Out:
# 1354
# adl           953
# falling       285
# lying_down    116
# dtype: int64

# %% [markdown]
# ### Plot a frames series from first batch
#     The first two images are black, in fact they are padding frames, because those two frames in the dataframe were part of another sequence. In other words, such frames had a different camera number with respect to the others.

# %%
# get first batch from train generator

batch_number = randrange(0, 200)

batch_X, batch_y = train_gen.__getitem__(100)
print("batch_X.shape:", batch_X.shape, "batch_y.shape:", batch_y.shape)

window_number = randrange(0, 15)

frames = batch_X[window_number]
title = np.expand_dims(batch_y[window_number], axis=0)
title = le.inverse_transform(title)[0]
title

show_frames_series(frames, title, figsize=(20, 10), nrows=4)
# Out:
# batch_X.shape: (16, 16, 112, 112, 3) batch_y.shape: (16, 3)

# %% [markdown]
# ### Metrics

# %%
# we keep track of the recall (sensitivity, or number of correctly predicted true positive).
# This metric is especially important for the fall class, where we want to have maximum recall to be sure we don't miss any fall event.
metrics = [
    tf.keras.metrics.CategoricalAccuracy(),
    tf.keras.metrics.Recall(class_id=0, name="adl"),
    tf.keras.metrics.Recall(class_id=1, name="fall"),
    tf.keras.metrics.Recall(class_id=2, name="lying_down"),
]

# %% [markdown]
# ### Callbacks

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{MED_FALL}/vision/models/3DCNN+ConvLSTM2D.h5"
)

callbacks = [model_checkpoint]

# %% [markdown]
# ## Define 3D CNN Model
# Architecture taken from:
# Tran, D., Bourdev, L., Fergus, R., Torresani, L., & Paluri, M. (2015). Learning spatiotemporal features with 3d convolutional networks. In Proceedings of the IEEE international conference on computer vision (pp. 4489-4497).

# %% [markdown]
# ![3d cnn architecture.png](attachment:d2a6e10e-5e28-4b25-9b09-f24b5cc5e52b.png)

# %% [markdown]
# ## Added ConvLSTM2D layers to the 3D CNN architecture

# %%
model = Sequential()
model.add(layers.Input(shape=(SEQ_LEN,) + INPUT_SHAPE))
model.add(layers.Rescaling(scale=1.0 / 255))
model.add(layers.Conv3D(64, (3, 3, 3), activation="relu", padding="same"))
model.add(layers.MaxPooling3D((1, 2, 2), strides=(1, 1, 1), padding="same"))
model.add(layers.BatchNormalization())
# model.add(layers.Dropout(0.3))

model.add(layers.Conv3D(128, (3, 3, 3), activation="relu", padding="same"))
model.add(layers.MaxPooling3D((2, 2, 2), padding="same"))
model.add(layers.BatchNormalization())
# model.add(layers.Dropout(0.3))

model.add(layers.Conv3D(256, (3, 3, 3), activation="relu", padding="same"))
model.add(layers.Conv3D(256, (2, 2, 2), activation="relu", padding="same"))
model.add(layers.MaxPooling3D((2, 2, 2), padding="same"))
model.add(layers.BatchNormalization())
# model.add(layers.Dropout(0.3))

model.add(layers.Conv3D(512, (3, 3, 3), activation="relu", padding="same"))
model.add(layers.Conv3D(512, (2, 2, 2), activation="relu", padding="same"))
model.add(layers.MaxPooling3D((2, 2, 2), padding="same"))
model.add(layers.BatchNormalization())
# model.add(layers.Dropout(0.3))

model.add(layers.Conv3D(512, (3, 3, 3), activation="relu", padding="same"))
model.add(layers.Conv3D(512, (2, 2, 2), activation="relu", padding="same"))
model.add(layers.MaxPooling3D((2, 2, 2), padding="same"))
model.add(layers.BatchNormalization())
# model.add(layers.Dropout(0.3))

model.add(layers.ConvLSTM2D(256, (3, 3), return_sequences=True))
model.add(layers.BatchNormalization())

model.add(layers.Dropout(0.3))
model.add(layers.ConvLSTM2D(128, (3, 3)))
model.add(layers.BatchNormalization())

model.add(layers.Flatten())
model.add(layers.Dense(3, "softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 16, 112, 112, 3)   0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 16, 112, 112, 64)  5248
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 16, 112, 112, 64)  0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 112, 112, 64)  256
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 16, 112, 112, 128) 221312
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 8, 56, 56, 128)    0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 56, 56, 128)    512
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 8, 56, 56, 256)    884992
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 8, 56, 56, 256)    524544
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 4, 28, 28, 256)    0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 28, 28, 256)    1024
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 4, 28, 28, 512)    3539456
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 4, 28, 28, 512)    2097664
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 2, 14, 14, 512)    0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 14, 14, 512)    2048
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 2, 14, 14, 512)    7078400
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 2, 14, 14, 512)    2097664
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 1, 7, 7, 512)      0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 7, 7, 512)      2048
# _________________________________________________________________
# conv_lst_m2d (ConvLSTM2D)    (None, 1, 5, 5, 256)      7078912
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1, 5, 5, 256)      1024
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 5, 5, 256)      0
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, 3, 3, 128)         1769984
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 3459
# =================================================================
# Total params: 25,309,059
# Trainable params: 25,305,347
# Non-trainable params: 3,712
# _________________________________________________________________

# %% [markdown]
# ### Compile Model

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=metrics)

# %% [markdown]
# ### Fit Model

# %%
history = model.fit(train_gen, validation_data=val_gen, epochs=20)
# Out:
# 2022-08-27 13:26:49.227072: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
# 2022-08-27 13:26:53.105566: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8201
# 2022-08-27 13:27:01.288824: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1354/1354 [==============================] - 884s 629ms/step - loss: 0.7561 - categorical_accuracy: 0.7117 - adl: 0.8430 - fall: 0.3731 - lying_down: 0.1077 - val_loss: 1.0162 - val_categorical_accuracy: 0.6650 - val_adl: 0.7491 - val_fall: 0.4407 - val_lying_down: 0.0400
# Epoch 2/20
# 1354/1354 [==============================] - 851s 629ms/step - loss: 0.5666 - categorical_accuracy: 0.7711 - adl: 0.8873 - fall: 0.4987 - lying_down: 0.1667 - val_loss: 0.8786 - val_categorical_accuracy: 0.7002 - val_adl: 0.8879 - val_fall: 0.3194 - val_lying_down: 0.0000e+00
# Epoch 3/20
# 1354/1354 [==============================] - 851s 628ms/step - loss: 0.6078 - categorical_accuracy: 0.7482 - adl: 0.8739 - fall: 0.4298 - lying_down: 0.0974 - val_loss: 1.1452 - val_categorical_accuracy: 0.5997 - val_adl: 0.7522 - val_fall: 0.2134 - val_lying_down: 0.1600
# Epoch 4/20
# 1354/1354 [==============================] - 850s 628ms/step - loss: 0.5155 - categorical_accuracy: 0.7837 - adl: 0.8980 - fall: 0.5101 - lying_down: 0.1403 - val_loss: 0.8316 - val_categorical_accuracy: 0.6368 - val_adl: 0.7161 - val_fall: 0.3270 - val_lying_down: 0.0000e+00
# Epoch 5/20
# 1354/1354 [==============================] - 851s 628ms/step - loss: 0.5035 - categorical_accuracy: 0.7910 - adl: 0.9032 - fall: 0.5268 - lying_down: 0.1432 - val_loss: 0.6308 - val_categorical_accuracy: 0.7655 - val_adl: 0.8394 - val_fall: 0.5758 - val_lying_down: 0.0400
# Epoch 6/20
# 1354/1354 [==============================] - 850s 628ms/step - loss: 0.4664 - categorical_accuracy: 0.8015 - adl: 0.9110 - fall: 0.5629 - lying_down: 0.1397 - val_loss: 0.7899 - val_categorical_accuracy: 0.7010 - val_adl: 0.8194 - val_fall: 0.4331 - val_lying_down: 0.0200
# Epoch 7/20
# 1354/1354 [==============================] - 850s 628ms/step - loss: 0.4890 - categorical_accuracy: 0.7959 - adl: 0.9062 - fall: 0.5501 - lying_down: 0.1535 - val_loss: 0.7924 - val_categorical_accuracy: 0.6883 - val_adl: 0.7379 - val_fall: 0.5253 - val_lying_down: 0.0400
# Epoch 8/20
# 1354/1354 [==============================] - 851s 628ms/step - loss: 0.4550 - categorical_accuracy: 0.8121 - adl: 0.9200 - fall: 0.5762 - lying_down: 0.1672 - val_loss: 0.7615 - val_categorical_accuracy: 0.7067 - val_adl: 0.7740 - val_fall: 0.5303 - val_lying_down: 0.1000
# Epoch 9/20
# 1354/1354 [==============================] - 851s 628ms/step - loss: 0.4175 - categorical_accuracy: 0.8267 - adl: 0.9274 - fall: 0.6162 - lying_down: 0.1999 - val_loss: 0.6928 - val_categorical_accuracy: 0.7324 - val_adl: 0.7783 - val_fall: 0.6338 - val_lying_down: 0.0600
# Epoch 10/20
# 1354/1354 [==============================] - 850s 628ms/step - loss: 0.4199 - categorical_accuracy: 0.8242 - adl: 0.9282 - fall: 0.6141 - lying_down: 0.1844 - val_loss: 0.5850 - val_categorical_accuracy: 0.7717 - val_adl: 0.8686 - val_fall: 0.4811 - val_lying_down: 0.0400
# Epoch 11/20
# 1354/1354 [==============================] - 850s 627ms/step - loss: 0.4006 - categorical_accuracy: 0.8299 - adl: 0.9320 - fall: 0.6332 - lying_down: 0.1867 - val_loss: 0.6096 - val_categorical_accuracy: 0.7614 - val_adl: 0.8151 - val_fall: 0.5720 - val_lying_down: 0.0000e+00
# Epoch 12/20
# 1354/1354 [==============================] - 850s 628ms/step - loss: 0.4221 - categorical_accuracy: 0.8219 - adl: 0.9280 - fall: 0.6220 - lying_down: 0.1661 - val_loss: 0.6970 - val_categorical_accuracy: 0.7055 - val_adl: 0.7553 - val_fall: 0.4912 - val_lying_down: 0.1400
# Epoch 13/20
# 1354/1354 [==============================] - 850s 627ms/step - loss: 0.3767 - categorical_accuracy: 0.8385 - adl: 0.9388 - fall: 0.6441 - lying_down: 0.2159 - val_loss: 0.5863 - val_categorical_accuracy: 0.7659 - val_adl: 0.8200 - val_fall: 0.6604 - val_lying_down: 0.0200
# Epoch 14/20
# 1354/1354 [==============================] - 850s 627ms/step - loss: 0.3931 - categorical_accuracy: 0.8354 - adl: 0.9349 - fall: 0.6408 - lying_down: 0.1850 - val_loss: 0.7306 - val_categorical_accuracy: 0.7108 - val_adl: 0.7615 - val_fall: 0.5556 - val_lying_down: 0.1400
# Epoch 15/20
# 1354/1354 [==============================] - 850s 628ms/step - loss: 0.3924 - categorical_accuracy: 0.8314 - adl: 0.9314 - fall: 0.6330 - lying_down: 0.2102 - val_loss: 0.6317 - val_categorical_accuracy: 0.6953 - val_adl: 0.7927 - val_fall: 0.3864 - val_lying_down: 0.0200
# Epoch 16/20
#   41/1354 [..............................] - ETA: 13:17 - loss: 0.3801 - categorical_accuracy: 0.8308 - adl: 0.9568 - fall: 0.7260 - lying_down: 0.2473

# %%
model.save(f"{MED_FALL}/vision/models/3DCNN+ConvLSTM2D.h5")

# %%
model = tf.keras.models.load_model(f"{MED_FALL}/vision/models/3DCNN+ConvLSTM2D.h5")

# %%
model.fit(train_gen, validation_data=val_gen, epochs=50, callbacks=callbacks)
# Out:
# Epoch 1/50
# 1354/1354 [==============================] - 852s 628ms/step - loss: 0.3331 - categorical_accuracy: 0.8578 - adl: 0.9445 - fall: 0.6779 - lying_down: 0.3139 - val_loss: 0.5666 - val_categorical_accuracy: 0.7655 - val_adl: 0.8574 - val_fall: 0.5619 - val_lying_down: 0.0400
# Epoch 2/50
# 1354/1354 [==============================] - 849s 627ms/step - loss: 0.3289 - categorical_accuracy: 0.8594 - adl: 0.9438 - fall: 0.6908 - lying_down: 0.3018 - val_loss: 0.5883 - val_categorical_accuracy: 0.7647 - val_adl: 0.8032 - val_fall: 0.5619 - val_lying_down: 0.0400
# Epoch 3/50
# 1354/1354 [==============================] - 849s 627ms/step - loss: 0.3344 - categorical_accuracy: 0.8582 - adl: 0.9457 - fall: 0.6860 - lying_down: 0.3207 - val_loss: 0.6353 - val_categorical_accuracy: 0.7341 - val_adl: 0.7740 - val_fall: 0.5997 - val_lying_down: 0.1600
# Epoch 4/50
# 1354/1354 [==============================] - 850s 627ms/step - loss: 0.3230 - categorical_accuracy: 0.8593 - adl: 0.9461 - fall: 0.7007 - lying_down: 0.3150 - val_loss: 0.6153 - val_categorical_accuracy: 0.7398 - val_adl: 0.8026 - val_fall: 0.5619 - val_lying_down: 0.1000
# Epoch 5/50
# 1081/1354 [======================>.......] - ETA: 2:45 - loss: 0.3314 - categorical_accuracy: 0.8584 - adl: 0.9451 - fall: 0.6860 - lying_down: 0.3252

# %%
y_logits = model.predict(val_gen)
print(y_logits.shape)
# Out:
# (2448, 3)

# %%
y_preds_encoded = []
for logit in y_logits:
    one_hot_labl = [0, 0, 0]
    argmax = np.argmax(logit, axis=0)
    one_hot_labl[argmax] = 1
    y_preds_encoded.append(one_hot_labl)

y_preds_encoded

# %%
len(val_gen.windows_labels)
# Out:
# 2460

# %%
y_true = val_gen.windows_labels[0:2448]
pd.Series(y_true).value_counts()
# Out:
# adl           1825
# falling        572
# lying_down      51
# dtype: int64

# %%
y_true_encoded = le.transform(y_true)

# %%
print(
    classification_report(
        y_true=y_true_encoded,
        y_pred=y_preds_encoded,
        target_names=["adl", "fall", "lie_down"],
    ),
)
# Out:
#               precision    recall  f1-score   support
#
#          adl       0.76      0.69      0.73      1825
#         fall       0.26      0.30      0.28       572
#     lie_down       0.01      0.02      0.01        51
#
#    micro avg       0.59      0.59      0.59      2448
#    macro avg       0.34      0.34      0.34      2448
# weighted avg       0.63      0.59      0.61      2448
#  samples avg       0.59      0.59      0.59      2448

# %%
model.evaluate(val_gen)
# Out:
# 153/153 [==============================] - 28s 183ms/step - loss: 0.6172 - categorical_accuracy: 0.7688 - adl: 0.8381 - fall: 0.5253 - lying_down: 0.1000
# [0.6172025799751282,
#  0.7687908411026001,
#  0.8381071090698242,
#  0.5252525210380554,
#  0.10000000149011612]
