# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
#%load_ext lab_black
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from random import randrange
import tensorflow as tf
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.metrics import classification_report

from utils.utility_functions import listdir_nohidden_sorted as lsdir
from vision.vision_utils.video_seq_generator import VideoSeqGenerator

# %% [markdown]
# ### Paths

# %%
MED_FALL = "/home/jovyan/work/MED_Fall"
GROUND_TRUTH_PATH = f"{MED_FALL}/vision/vision_dataset/ground_truth_new"
FRAMES_PATH = f"{MED_FALL}/vision/vision_dataset/extracted_frames"

# %% [markdown]
# ### Hyperparameters

# %%
SEQ_LEN: int = 16
STRIDE: int = 8
BATCH_SIZE: int = 16
INPUT_SHAPE: tuple[int, int, int] = (112, 112, 3)

# %% [markdown]
# ### Utility Functions

# %%
def get_cam(name: str) -> int:
    """
    Extract cam number from each video frame name
    ------

    arguments:
        - name: string containing the frame name. Examle: 'Actor_1_bed_cam_1_0000'

    outputs:
        - cam_number: integer containg the cam number of the provided frame name.
                    Example: if name is 'Actor_1_bed_cam_1_0000', cam_number is: 1.
    """

    start = name.find("cam_")
    ind = start + 4
    cam_number = name[ind]
    return int(cam_number)


def show_frames_series(
    frames_series: np.array, title: str, figsize: tuple[int, int] = (20, 20), nrows=5
):
    """
    plot a series of SEQ_LEN frames with respective labels as titles.
    --------

    arguments:
        - frames_series: np.array containg SEQ_LEN images.
        - title: strcontainging the label of the series of frame. The label is calculated as the mode (most frequent label) of the single frames' labels.
        - fig_size: Optional. Tuple of two integers containing the figure dimensions for the plot. Default is (20, 20).

    """
    rows = nrows

    fig = plt.figure(figsize=figsize)
    for n, image in enumerate(frames_series):
        a = fig.add_subplot(rows, int(len(frames_series) / float(rows)), n + 1)

        plt.imshow(image)
        plt.axis("off")
    fig.suptitle(title)
    plt.show()

# %% [markdown]
# ## Load Dataset

# %%
# Load all csv files (one per actor). Each file contains frames names and respective labels.
dfs = []
for file in lsdir(GROUND_TRUTH_PATH):
    df = pd.read_csv(file)
    dfs.append(df)
# concatenate all csv files in one pandas DF
dataset = pd.concat(dfs, ignore_index=True, axis=0)
dataset = dataset.iloc[:, 2:]
dataset
# Out:
#                 micro_labels macro_labels            ar_labels  \
# 0                  lie_still   lying_down  actor_repositioning
# 1                  lie_still   lying_down  actor_repositioning
# 2                  lie_still   lying_down  actor_repositioning
# 3                  lie_still   lying_down  actor_repositioning
# 4                  lie_still   lying_down  actor_repositioning
# ...                      ...          ...                  ...
# 1182295  stand_up_from_floor          adl  actor_repositioning
# 1182296  stand_up_from_floor          adl  actor_repositioning
# 1182297  stand_up_from_floor          adl  actor_repositioning
# 1182298  stand_up_from_floor          adl  actor_repositioning
# 1182299  stand_up_from_floor          adl  actor_repositioning
#
#                                frame_name
# 0                  actor_1_bed_cam_1_0000
# 1                  actor_1_bed_cam_1_0001
# 2                  actor_1_bed_cam_1_0002
# 3                  actor_1_bed_cam_1_0003
# 4                  actor_1_bed_cam_1_0004
# ...                                   ...
# 1182295  actor_4_chair_full_ph_cam_7_4615
# 1182296  actor_4_chair_full_ph_cam_7_4616
# 1182297  actor_4_chair_full_ph_cam_7_4617
# 1182298  actor_4_chair_full_ph_cam_7_4618
# 1182299  actor_4_chair_full_ph_cam_7_4619
#
# [1182300 rows x 4 columns]

# %%
# Select only "on_air" frames (where actors are performing sequences)
dataset_onair = dataset.loc[dataset["ar_labels"] == "on_air"].copy()
dataset_onair
# Out:
#               micro_labels macro_labels ar_labels  \
# 206      sit_up_from_lying          adl    on_air
# 207      sit_up_from_lying          adl    on_air
# 208      sit_up_from_lying          adl    on_air
# 209      sit_up_from_lying          adl    on_air
# 210      sit_up_from_lying          adl    on_air
# ...                    ...          ...       ...
# 1182213     crouched_still      falling    on_air
# 1182214     crouched_still      falling    on_air
# 1182215     crouched_still      falling    on_air
# 1182216     crouched_still      falling    on_air
# 1182217     crouched_still      falling    on_air
#
#                                frame_name
# 206                actor_1_bed_cam_1_0206
# 207                actor_1_bed_cam_1_0207
# 208                actor_1_bed_cam_1_0208
# 209                actor_1_bed_cam_1_0209
# 210                actor_1_bed_cam_1_0210
# ...                                   ...
# 1182213  actor_4_chair_full_ph_cam_7_4533
# 1182214  actor_4_chair_full_ph_cam_7_4534
# 1182215  actor_4_chair_full_ph_cam_7_4535
# 1182216  actor_4_chair_full_ph_cam_7_4536
# 1182217  actor_4_chair_full_ph_cam_7_4537
#
# [386106 rows x 4 columns]

# %%
# check on_air dataset samples per class
dataset_onair["macro_labels"].value_counts()
# Out:
# adl           269836
# falling        88312
# lying_down     27958
# Name: macro_labels, dtype: int64

# %%
# instantiate and fit a OneHotEncoder for the macro classes (adl, fall, lie_down)
le = LabelBinarizer()
le.fit(dataset_onair["macro_labels"])
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
le_name_mapping
# Out:
# {'adl': array([1, 0, 0]),
#  'falling': array([0, 1, 0]),
#  'lying_down': array([0, 0, 1])}

# %% [markdown]
# ## Use actor 4 as test set

# %%
actor_4 = dataset_onair.loc[dataset_onair["frame_name"].str.contains("actor_4")].copy()

# %%
actor_123 = dataset_onair.drop(actor_4.index)
actor_123
# Out:
#                   micro_labels macro_labels ar_labels  \
# 206          sit_up_from_lying          adl    on_air
# 207          sit_up_from_lying          adl    on_air
# 208          sit_up_from_lying          adl    on_air
# 209          sit_up_from_lying          adl    on_air
# 210          sit_up_from_lying          adl    on_air
# ...                        ...          ...       ...
# 1013767  lie_down_on_the_floor   lying_down    on_air
# 1013768  lie_down_on_the_floor   lying_down    on_air
# 1013769  lie_down_on_the_floor   lying_down    on_air
# 1013770  lie_down_on_the_floor   lying_down    on_air
# 1013771  lie_down_on_the_floor   lying_down    on_air
#
#                                     frame_name
# 206                     actor_1_bed_cam_1_0206
# 207                     actor_1_bed_cam_1_0207
# 208                     actor_1_bed_cam_1_0208
# 209                     actor_1_bed_cam_1_0209
# 210                     actor_1_bed_cam_1_0210
# ...                                        ...
# 1013767  actor_3_walk_stick_full_ph_cam_7_5767
# 1013768  actor_3_walk_stick_full_ph_cam_7_5768
# 1013769  actor_3_walk_stick_full_ph_cam_7_5769
# 1013770  actor_3_walk_stick_full_ph_cam_7_5770
# 1013771  actor_3_walk_stick_full_ph_cam_7_5771
#
# [346738 rows x 4 columns]

# %%
train_set = actor_123

# %%
train_set["macro_labels"].value_counts()
# Out:
# adl           244132
# falling        75320
# lying_down     27286
# Name: macro_labels, dtype: int64

# %%
test_set = actor_4
test_set["macro_labels"].value_counts()
# Out:
# adl           25704
# falling       12992
# lying_down      672
# Name: macro_labels, dtype: int64

# %% [markdown]
# ## Balance dataset

# %%
# dataset_balanced = dataset_onair.copy()  # make a copy of on_air dataset

counts = train_set["macro_labels"].value_counts()  # count samples per class
minority_class_samples = counts[-1]  # store minority class samples

# select adl samples
adl_samples = train_set.loc[dataset["macro_labels"] == "adl"]

# select fall samples
fall_samples = train_set.loc[dataset["macro_labels"] == "falling"]

## subsample

# count exceeding adl samples wrt minority_class_samples
adl_todrop_ind = len(adl_samples) - minority_class_samples
# count exceeding fall samples wrt minority_class_samples
fall_todrop_ind = len(fall_samples) - minority_class_samples

# select indices to drop from adl subset
adl_samples_to_drop = adl_samples.iloc[-adl_todrop_ind:]

# select indices to drop from fall subset
fall_samples_to_drop = fall_samples.iloc[-fall_todrop_ind:]

# actually drop exceeding adl samples
train_set.drop(adl_samples_to_drop.index, axis=0, inplace=True)

# actually drop exceeding fall samples
train_set.drop(fall_samples_to_drop.index, axis=0, inplace=True)

# count samples per class of the balanced dataset
train_set["macro_labels"].value_counts()
# Out:
# adl           27286
# falling       27286
# lying_down    27286
# Name: macro_labels, dtype: int64

# %%
train_set.sort_index(inplace=True)

# %%
adl_samples = train_set.loc[dataset["macro_labels"] == "adl"]
fall_samples = train_set.loc[dataset["macro_labels"] == "falling"]
lie_down_samples = train_set.loc[dataset["macro_labels"] == "lying_down"]

split_ratio = 0.8
split_adl = int(len(adl_samples) * split_ratio)
split_fall = int(len(fall_samples) * split_ratio)
split_lie_down = int(len(lie_down_samples) * split_ratio)

val_adl = adl_samples.iloc[split_adl:].copy()
val_fall = fall_samples.iloc[split_fall:].copy()
val_lie_down = lie_down_samples.iloc[split_lie_down:].copy()

val_set = pd.concat([val_adl, val_fall, val_lie_down], axis=0)
val_set
# Out:
#                   micro_labels macro_labels ar_labels  \
# 113022             rolling_bed          adl    on_air
# 113023             rolling_bed          adl    on_air
# 113024             rolling_bed          adl    on_air
# 113025             rolling_bed          adl    on_air
# 113026             rolling_bed          adl    on_air
# ...                        ...          ...       ...
# 1013767  lie_down_on_the_floor   lying_down    on_air
# 1013768  lie_down_on_the_floor   lying_down    on_air
# 1013769  lie_down_on_the_floor   lying_down    on_air
# 1013770  lie_down_on_the_floor   lying_down    on_air
# 1013771  lie_down_on_the_floor   lying_down    on_air
#
#                                     frame_name
# 113022      actor_1_bed_rolling_ph2_cam_2_0882
# 113023      actor_1_bed_rolling_ph2_cam_2_0883
# 113024      actor_1_bed_rolling_ph2_cam_2_0884
# 113025      actor_1_bed_rolling_ph2_cam_2_0885
# 113026      actor_1_bed_rolling_ph2_cam_2_0886
# ...                                        ...
# 1013767  actor_3_walk_stick_full_ph_cam_7_5767
# 1013768  actor_3_walk_stick_full_ph_cam_7_5768
# 1013769  actor_3_walk_stick_full_ph_cam_7_5769
# 1013770  actor_3_walk_stick_full_ph_cam_7_5770
# 1013771  actor_3_walk_stick_full_ph_cam_7_5771
#
# [16374 rows x 4 columns]

# %%
train_set.drop(val_set.index, inplace=True)
train_set
# Out:
#                  micro_labels macro_labels ar_labels  \
# 206         sit_up_from_lying          adl    on_air
# 207         sit_up_from_lying          adl    on_air
# 208         sit_up_from_lying          adl    on_air
# 209         sit_up_from_lying          adl    on_air
# 210         sit_up_from_lying          adl    on_air
# ...                       ...          ...       ...
# 635802  lie_down_on_the_floor   lying_down    on_air
# 635803  lie_down_on_the_floor   lying_down    on_air
# 635804  lie_down_on_the_floor   lying_down    on_air
# 635805  lie_down_on_the_floor   lying_down    on_air
# 635806  lie_down_on_the_floor   lying_down    on_air
#
#                          frame_name
# 206          actor_1_bed_cam_1_0206
# 207          actor_1_bed_cam_1_0207
# 208          actor_1_bed_cam_1_0208
# 209          actor_1_bed_cam_1_0209
# 210          actor_1_bed_cam_1_0210
# ...                             ...
# 635802  actor_2_chair_ph_cam_4_1302
# 635803  actor_2_chair_ph_cam_4_1303
# 635804  actor_2_chair_ph_cam_4_1304
# 635805  actor_2_chair_ph_cam_4_1305
# 635806  actor_2_chair_ph_cam_4_1306
#
# [65484 rows x 4 columns]

# %%
train_set["macro_labels"].value_counts()
# Out:
# adl           21828
# falling       21828
# lying_down    21828
# Name: macro_labels, dtype: int64

# %% [markdown]
# ## Instantiate train and val generators
# ### VideoSeqGenerator works as follows:
# - takes a dataframe containing the frame names and the corresponding labels as input
# - splits the dataframe in time series of length SEQ_LEN
# - for each series:
#     - loads a batch made of BATCH_SIZE * SEQ_LEN frames into a tensor called "X"
#     - for each window (time-series) of the batch caluculates the mode of the frames, applies OneHotEncoding and stores the encoded windows' labels in a tensor called "y".
#     - returns X,y.
#       X has shape (BATCH_SIZE, SEQ_LEN, IMAGE_SIZE), for example (32, 20, 224, 224, 3)
#       y has shape (BATCH_SIZE, 3),  where 3 derives from the one hot encoding of the 3 classes (adl, fall, lie_down)

# %%
# instantiating train generator. For this test there will be only one generator which takes the whole dataset as input
train_gen = VideoSeqGenerator(
    frames_path=FRAMES_PATH,
    df=train_set,
    seq_len=SEQ_LEN,
    stride=STRIDE,
    batch_size=BATCH_SIZE,
    label_encoder=le,
    input_shape=INPUT_SHAPE,
)
# Out:
# (112, 112, 3)
# <class 'tuple'>

# %%
val_gen = VideoSeqGenerator(
    frames_path=FRAMES_PATH,
    df=val_set,
    seq_len=SEQ_LEN,
    batch_size=BATCH_SIZE,
    stride=STRIDE,
    label_encoder=le,
    input_shape=INPUT_SHAPE,
)
# Out:
# (112, 112, 3)
# <class 'tuple'>

# %%
train_gen.df["macro_labels"].value_counts()
# Out:
# adl           21828
# falling       21828
# lying_down    21828
# Name: macro_labels, dtype: int64

# %% [markdown]
# ### Plot a frames series from first batch
#     The first two images are black, in fact they are padding frames, because those two frames in the dataframe were part of another sequence. In other words, such frames had a different camera number with respect to the others.

# %%
# get first batch from train generator

batch_number = randrange(0, 100)

batch_X, batch_y = train_gen.__getitem__(batch_number)
print("batch_X.shape:", batch_X.shape, "batch_y.shape:", batch_y.shape)

window_number = randrange(0, 3)

frames = batch_X[window_number]
title = np.expand_dims(batch_y[window_number], axis=0)
title = le.inverse_transform(title)[0]
title

show_frames_series(frames, title, figsize=(20, 10), nrows=4)
# Out:
# batch_X.shape: (16, 16, 112, 112, 3) batch_y.shape: (16, 3)

# %% [markdown]
# ### Metrics

# %%
# we keep track of the recall (sensitivity, or number of correctly predicted true positive).
# This metric is especially important for the fall class, where we want to have maximum recall to be sure we don't miss any fall event.
metrics = [
    tf.keras.metrics.CategoricalAccuracy(),
    tf.keras.metrics.Recall(class_id=0, name="adl"),
    tf.keras.metrics.Recall(class_id=1, name="fall"),
    tf.keras.metrics.Recall(class_id=2, name="lying_down"),
]
# Out:
# 2022-08-29 15:09:03.925063: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-29 15:09:04.699835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21793 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:65:00.0, compute capability: 8.6

# %% [markdown]
# ### Callbacks

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{MED_FALL}/vision/models/3DCNN+ConvLSTM2D_actor123_balanced.h5"
)

callbacks = [model_checkpoint]

# %% [markdown]
# ## Define 3D CNN Model
# Architecture taken from:
# Tran, D., Bourdev, L., Fergus, R., Torresani, L., & Paluri, M. (2015). Learning spatiotemporal features with 3d convolutional networks. In Proceedings of the IEEE international conference on computer vision (pp. 4489-4497).

# %% [markdown]
# ![3d cnn architecture.png](attachment:d2a6e10e-5e28-4b25-9b09-f24b5cc5e52b.png)

# %% [markdown]
# ## Added ConvLSTM2D layers to the 3D CNN architecture

# %%
model = Sequential()
model.add(layers.Input(shape=(SEQ_LEN,) + INPUT_SHAPE))
model.add(layers.Rescaling(scale=1.0 / 255))
model.add(layers.Conv3D(64, (3, 3, 3), activation="relu", padding="same"))
model.add(layers.MaxPooling3D((1, 2, 2), strides=(1, 1, 1), padding="same"))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3))

model.add(layers.Conv3D(128, (3, 3, 3), activation="relu", padding="same"))
model.add(layers.MaxPooling3D((2, 2, 2), padding="same"))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3))

model.add(layers.Conv3D(256, (3, 3, 3), activation="relu", padding="same"))
model.add(layers.Conv3D(256, (2, 2, 2), activation="relu", padding="same"))
model.add(layers.MaxPooling3D((2, 2, 2), padding="same"))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3))

model.add(layers.Conv3D(512, (3, 3, 3), activation="relu", padding="same"))
model.add(layers.Conv3D(512, (2, 2, 2), activation="relu", padding="same"))
model.add(layers.MaxPooling3D((2, 2, 2), padding="same"))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3))

model.add(layers.Conv3D(512, (3, 3, 3), activation="relu", padding="same"))
model.add(layers.Conv3D(512, (2, 2, 2), activation="relu", padding="same"))
model.add(layers.MaxPooling3D((2, 2, 2), padding="same"))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3))

model.add(layers.ConvLSTM2D(256, (3, 3), return_sequences=True))
model.add(layers.BatchNormalization())

model.add(layers.Dropout(0.3))
model.add(layers.ConvLSTM2D(128, (3, 3)))
model.add(layers.BatchNormalization())

model.add(layers.Flatten())
model.add(layers.Dense(3, "softmax"))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 16, 112, 112, 3)   0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 16, 112, 112, 64)  5248
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 16, 112, 112, 64)  0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 112, 112, 64)  256
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 112, 112, 64)  0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 16, 112, 112, 128) 221312
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 8, 56, 56, 128)    0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 56, 56, 128)    512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 56, 56, 128)    0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 8, 56, 56, 256)    884992
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 8, 56, 56, 256)    524544
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 4, 28, 28, 256)    0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 28, 28, 256)    1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 28, 28, 256)    0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 4, 28, 28, 512)    3539456
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 4, 28, 28, 512)    2097664
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 2, 14, 14, 512)    0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 14, 14, 512)    2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 14, 14, 512)    0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 2, 14, 14, 512)    7078400
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 2, 14, 14, 512)    2097664
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 1, 7, 7, 512)      0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 7, 7, 512)      2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 7, 7, 512)      0
# _________________________________________________________________
# conv_lst_m2d (ConvLSTM2D)    (None, 1, 5, 5, 256)      7078912
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1, 5, 5, 256)      1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 5, 5, 256)      0
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, 3, 3, 128)         1769984
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 3459
# =================================================================
# Total params: 25,309,059
# Trainable params: 25,305,347
# Non-trainable params: 3,712
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model,
    to_file="/home/jovyan/work/model_plots/3DCNN+ConvLSTM2D.png",)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# ### Compile Model

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=metrics)

# %% [markdown]
# ### Fit Model

# %%
history = model.fit(train_gen, validation_data=val_gen, epochs=50)
# Out:
# 2022-08-29 15:09:07.662630: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-08-29 15:09:16.408779: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8201
# 2022-08-29 15:09:25.520229: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 255/255 [==============================] - 217s 704ms/step - loss: 1.6979 - categorical_accuracy: 0.4463 - adl: 0.5689 - fall: 0.3056 - lying_down: 0.3629 - val_loss: 1.3813 - val_categorical_accuracy: 0.2877 - val_adl: 0.1532 - val_fall: 0.2836 - val_lying_down: 0.1437
# Epoch 2/50
# 255/255 [==============================] - 180s 703ms/step - loss: 1.1839 - categorical_accuracy: 0.4890 - adl: 0.6455 - fall: 0.3101 - lying_down: 0.3629 - val_loss: 1.4110 - val_categorical_accuracy: 0.3810 - val_adl: 0.2803 - val_fall: 0.3450 - val_lying_down: 0.3969
# Epoch 3/50
# 255/255 [==============================] - 180s 705ms/step - loss: 0.9070 - categorical_accuracy: 0.5789 - adl: 0.7627 - fall: 0.3902 - lying_down: 0.4393 - val_loss: 1.6494 - val_categorical_accuracy: 0.3909 - val_adl: 0.1821 - val_fall: 0.5848 - val_lying_down: 0.3094
# Epoch 4/50
# 255/255 [==============================] - 179s 700ms/step - loss: 0.7011 - categorical_accuracy: 0.6782 - adl: 0.8666 - fall: 0.4770 - lying_down: 0.5585 - val_loss: 1.6808 - val_categorical_accuracy: 0.3542 - val_adl: 0.1329 - val_fall: 0.5731 - val_lying_down: 0.2625
# Epoch 5/50
# 255/255 [==============================] - 180s 703ms/step - loss: 0.6648 - categorical_accuracy: 0.6926 - adl: 0.8666 - fall: 0.5015 - lying_down: 0.6073 - val_loss: 2.0361 - val_categorical_accuracy: 0.4296 - val_adl: 0.1532 - val_fall: 0.4152 - val_lying_down: 0.4844
# Epoch 6/50
# 255/255 [==============================] - 179s 699ms/step - loss: 0.6496 - categorical_accuracy: 0.7118 - adl: 0.8585 - fall: 0.5705 - lying_down: 0.6015 - val_loss: 1.7383 - val_categorical_accuracy: 0.4157 - val_adl: 0.2110 - val_fall: 0.4854 - val_lying_down: 0.4563
# Epoch 7/50
# 255/255 [==============================] - 180s 703ms/step - loss: 0.5969 - categorical_accuracy: 0.7262 - adl: 0.8968 - fall: 0.5690 - lying_down: 0.6480 - val_loss: 2.0643 - val_categorical_accuracy: 0.4325 - val_adl: 0.0751 - val_fall: 0.4474 - val_lying_down: 0.7125
# Epoch 8/50
# 255/255 [==============================] - 179s 700ms/step - loss: 0.5846 - categorical_accuracy: 0.7328 - adl: 0.8931 - fall: 0.5883 - lying_down: 0.6349 - val_loss: 1.6661 - val_categorical_accuracy: 0.3661 - val_adl: 0.2775 - val_fall: 0.4678 - val_lying_down: 0.2906
# Epoch 9/50
# 255/255 [==============================] - 181s 706ms/step - loss: 0.5856 - categorical_accuracy: 0.7267 - adl: 0.9057 - fall: 0.5801 - lying_down: 0.6167 - val_loss: 1.9678 - val_categorical_accuracy: 0.4375 - val_adl: 0.1040 - val_fall: 0.5088 - val_lying_down: 0.6375
# Epoch 10/50
# 255/255 [==============================] - 180s 706ms/step - loss: 0.5247 - categorical_accuracy: 0.7647 - adl: 0.9145 - fall: 0.6298 - lying_down: 0.6953 - val_loss: 1.9710 - val_categorical_accuracy: 0.3978 - val_adl: 0.1214 - val_fall: 0.5380 - val_lying_down: 0.4344
# Epoch 11/50
# 255/255 [==============================] - 179s 701ms/step - loss: 0.5622 - categorical_accuracy: 0.7444 - adl: 0.9071 - fall: 0.6172 - lying_down: 0.6509 - val_loss: 2.1666 - val_categorical_accuracy: 0.3998 - val_adl: 0.1532 - val_fall: 0.3830 - val_lying_down: 0.6187
# Epoch 12/50
# 255/255 [==============================] - 162s 635ms/step - loss: 0.6034 - categorical_accuracy: 0.7240 - adl: 0.8850 - fall: 0.5742 - lying_down: 0.6415 - val_loss: 1.7865 - val_categorical_accuracy: 0.3700 - val_adl: 0.1936 - val_fall: 0.3801 - val_lying_down: 0.4344
# Epoch 13/50
# 255/255 [==============================] - 161s 631ms/step - loss: 0.5289 - categorical_accuracy: 0.7593 - adl: 0.9138 - fall: 0.6276 - lying_down: 0.6865 - val_loss: 2.0824 - val_categorical_accuracy: 0.3988 - val_adl: 0.1474 - val_fall: 0.4854 - val_lying_down: 0.4437
# Epoch 14/50
# 255/255 [==============================] - 161s 630ms/step - loss: 0.5963 - categorical_accuracy: 0.7267 - adl: 0.8666 - fall: 0.5987 - lying_down: 0.6480 - val_loss: 1.9484 - val_categorical_accuracy: 0.4018 - val_adl: 0.3208 - val_fall: 0.4064 - val_lying_down: 0.4187
# Epoch 15/50
# 255/255 [==============================] - 161s 630ms/step - loss: 0.5750 - categorical_accuracy: 0.7458 - adl: 0.8954 - fall: 0.6142 - lying_down: 0.6756 - val_loss: 1.8732 - val_categorical_accuracy: 0.4534 - val_adl: 0.1185 - val_fall: 0.6316 - val_lying_down: 0.5125
# Epoch 16/50
# 255/255 [==============================] - 161s 629ms/step - loss: 0.5192 - categorical_accuracy: 0.7630 - adl: 0.9167 - fall: 0.6461 - lying_down: 0.6742 - val_loss: 2.2199 - val_categorical_accuracy: 0.4107 - val_adl: 0.1532 - val_fall: 0.4649 - val_lying_down: 0.5562
# Epoch 17/50
# 255/255 [==============================] - 161s 629ms/step - loss: 0.5061 - categorical_accuracy: 0.7779 - adl: 0.9204 - fall: 0.6595 - lying_down: 0.7185 - val_loss: 1.9081 - val_categorical_accuracy: 0.3948 - val_adl: 0.1387 - val_fall: 0.5292 - val_lying_down: 0.4906
# Epoch 18/50
# 255/255 [==============================] - 161s 631ms/step - loss: 0.4944 - categorical_accuracy: 0.7765 - adl: 0.9315 - fall: 0.6691 - lying_down: 0.6815 - val_loss: 1.9316 - val_categorical_accuracy: 0.3681 - val_adl: 0.2341 - val_fall: 0.2310 - val_lying_down: 0.5500
# Epoch 19/50
# 255/255 [==============================] - 161s 629ms/step - loss: 0.4810 - categorical_accuracy: 0.7873 - adl: 0.9263 - fall: 0.6647 - lying_down: 0.7316 - val_loss: 2.1512 - val_categorical_accuracy: 0.3839 - val_adl: 0.1272 - val_fall: 0.3743 - val_lying_down: 0.4688
# Epoch 20/50
# 255/255 [==============================] - 161s 631ms/step - loss: 0.4922 - categorical_accuracy: 0.7755 - adl: 0.9042 - fall: 0.6684 - lying_down: 0.7164 - val_loss: 2.3539 - val_categorical_accuracy: 0.3462 - val_adl: 0.0636 - val_fall: 0.4298 - val_lying_down: 0.5000
# Epoch 21/50
# 255/255 [==============================] - 161s 630ms/step - loss: 0.4797 - categorical_accuracy: 0.7865 - adl: 0.9307 - fall: 0.6788 - lying_down: 0.7076 - val_loss: 2.1974 - val_categorical_accuracy: 0.3730 - val_adl: 0.0780 - val_fall: 0.4825 - val_lying_down: 0.5250
# Epoch 22/50
# 255/255 [==============================] - 161s 629ms/step - loss: 0.4954 - categorical_accuracy: 0.7819 - adl: 0.9256 - fall: 0.6818 - lying_down: 0.7004 - val_loss: 1.9179 - val_categorical_accuracy: 0.3849 - val_adl: 0.1532 - val_fall: 0.5906 - val_lying_down: 0.2219
# Epoch 23/50
# 255/255 [==============================] - 161s 629ms/step - loss: 0.4951 - categorical_accuracy: 0.7762 - adl: 0.9256 - fall: 0.6484 - lying_down: 0.7113 - val_loss: 2.3218 - val_categorical_accuracy: 0.4325 - val_adl: 0.1127 - val_fall: 0.4357 - val_lying_down: 0.7156
# Epoch 24/50
# 255/255 [==============================] - 161s 630ms/step - loss: 0.4702 - categorical_accuracy: 0.7848 - adl: 0.9270 - fall: 0.6743 - lying_down: 0.7142 - val_loss: 1.9492 - val_categorical_accuracy: 0.2976 - val_adl: 0.1561 - val_fall: 0.2456 - val_lying_down: 0.4000
# Epoch 25/50
# 255/255 [==============================] - 176s 688ms/step - loss: 0.4824 - categorical_accuracy: 0.7757 - adl: 0.9211 - fall: 0.6625 - lying_down: 0.7047 - val_loss: 1.9940 - val_categorical_accuracy: 0.3770 - val_adl: 0.2399 - val_fall: 0.3421 - val_lying_down: 0.4938
# Epoch 26/50
# 255/255 [==============================] - 179s 702ms/step - loss: 0.4839 - categorical_accuracy: 0.7875 - adl: 0.9359 - fall: 0.6617 - lying_down: 0.7316 - val_loss: 2.1056 - val_categorical_accuracy: 0.4454 - val_adl: 0.1012 - val_fall: 0.6404 - val_lying_down: 0.5156
# Epoch 27/50
# 255/255 [==============================] - 179s 702ms/step - loss: 0.4464 - categorical_accuracy: 0.7953 - adl: 0.9359 - fall: 0.6766 - lying_down: 0.7375 - val_loss: 2.2126 - val_categorical_accuracy: 0.3929 - val_adl: 0.1387 - val_fall: 0.5263 - val_lying_down: 0.3844
# Epoch 28/50
# 255/255 [==============================] - 181s 709ms/step - loss: 0.4580 - categorical_accuracy: 0.7961 - adl: 0.9219 - fall: 0.6944 - lying_down: 0.7324 - val_loss: 2.3664 - val_categorical_accuracy: 0.3770 - val_adl: 0.1358 - val_fall: 0.3012 - val_lying_down: 0.5906
# Epoch 29/50
# 255/255 [==============================] - 181s 707ms/step - loss: 0.4816 - categorical_accuracy: 0.7983 - adl: 0.9160 - fall: 0.7040 - lying_down: 0.7295 - val_loss: 2.0826 - val_categorical_accuracy: 0.3710 - val_adl: 0.1705 - val_fall: 0.3713 - val_lying_down: 0.5500
# Epoch 30/50
# 255/255 [==============================] - 180s 707ms/step - loss: 0.4121 - categorical_accuracy: 0.8203 - adl: 0.9433 - fall: 0.7277 - lying_down: 0.7593 - val_loss: 2.2468 - val_categorical_accuracy: 0.4653 - val_adl: 0.1358 - val_fall: 0.5029 - val_lying_down: 0.7656
# Epoch 31/50
# 255/255 [==============================] - 181s 708ms/step - loss: 0.3914 - categorical_accuracy: 0.8265 - adl: 0.9433 - fall: 0.7426 - lying_down: 0.7535 - val_loss: 2.1582 - val_categorical_accuracy: 0.3938 - val_adl: 0.1416 - val_fall: 0.4357 - val_lying_down: 0.4906
# Epoch 32/50
# 255/255 [==============================] - 180s 705ms/step - loss: 0.3993 - categorical_accuracy: 0.8211 - adl: 0.9447 - fall: 0.7248 - lying_down: 0.7658 - val_loss: 2.3547 - val_categorical_accuracy: 0.3621 - val_adl: 0.0723 - val_fall: 0.3743 - val_lying_down: 0.6313
# Epoch 33/50
# 255/255 [==============================] - 181s 707ms/step - loss: 0.4060 - categorical_accuracy: 0.8152 - adl: 0.9396 - fall: 0.7129 - lying_down: 0.7651 - val_loss: 2.2091 - val_categorical_accuracy: 0.3938 - val_adl: 0.1098 - val_fall: 0.4795 - val_lying_down: 0.5625
# Epoch 34/50
# 255/255 [==============================] - 181s 710ms/step - loss: 0.3981 - categorical_accuracy: 0.8213 - adl: 0.9440 - fall: 0.7174 - lying_down: 0.7724 - val_loss: 2.0299 - val_categorical_accuracy: 0.3849 - val_adl: 0.1532 - val_fall: 0.4912 - val_lying_down: 0.4219
# Epoch 35/50
# 255/255 [==============================] - 181s 708ms/step - loss: 0.4172 - categorical_accuracy: 0.8176 - adl: 0.9352 - fall: 0.7196 - lying_down: 0.7607 - val_loss: 2.4861 - val_categorical_accuracy: 0.3562 - val_adl: 0.1156 - val_fall: 0.3158 - val_lying_down: 0.6031
# Epoch 36/50
# 255/255 [==============================] - 180s 707ms/step - loss: 0.3829 - categorical_accuracy: 0.8301 - adl: 0.9418 - fall: 0.7470 - lying_down: 0.7804 - val_loss: 2.2207 - val_categorical_accuracy: 0.4306 - val_adl: 0.1272 - val_fall: 0.4942 - val_lying_down: 0.6500
# Epoch 37/50
# 255/255 [==============================] - 180s 705ms/step - loss: 0.4032 - categorical_accuracy: 0.8189 - adl: 0.9396 - fall: 0.7122 - lying_down: 0.7825 - val_loss: 2.2916 - val_categorical_accuracy: 0.3343 - val_adl: 0.1127 - val_fall: 0.4240 - val_lying_down: 0.4156
# Epoch 38/50
# 255/255 [==============================] - 181s 709ms/step - loss: 0.3617 - categorical_accuracy: 0.8375 - adl: 0.9580 - fall: 0.7574 - lying_down: 0.7760 - val_loss: 2.4633 - val_categorical_accuracy: 0.4028 - val_adl: 0.1243 - val_fall: 0.5058 - val_lying_down: 0.5594
# Epoch 39/50
# 255/255 [==============================] - 181s 710ms/step - loss: 0.3457 - categorical_accuracy: 0.8512 - adl: 0.9477 - fall: 0.7856 - lying_down: 0.7964 - val_loss: 2.2283 - val_categorical_accuracy: 0.4117 - val_adl: 0.2168 - val_fall: 0.4444 - val_lying_down: 0.5219
# Epoch 40/50
# 255/255 [==============================] - 181s 709ms/step - loss: 0.3702 - categorical_accuracy: 0.8311 - adl: 0.9521 - fall: 0.7404 - lying_down: 0.7811 - val_loss: 2.4158 - val_categorical_accuracy: 0.3929 - val_adl: 0.1445 - val_fall: 0.3070 - val_lying_down: 0.7063
# Epoch 41/50
# 255/255 [==============================] - 181s 707ms/step - loss: 0.3390 - categorical_accuracy: 0.8534 - adl: 0.9536 - fall: 0.7641 - lying_down: 0.8204 - val_loss: 2.5692 - val_categorical_accuracy: 0.3452 - val_adl: 0.0809 - val_fall: 0.5322 - val_lying_down: 0.4187
# Epoch 42/50
# 255/255 [==============================] - 181s 709ms/step - loss: 0.3755 - categorical_accuracy: 0.8387 - adl: 0.9492 - fall: 0.7656 - lying_down: 0.7869 - val_loss: 2.5258 - val_categorical_accuracy: 0.3423 - val_adl: 0.1503 - val_fall: 0.3304 - val_lying_down: 0.5188
# Epoch 43/50
# 255/255 [==============================] - 180s 707ms/step - loss: 0.3628 - categorical_accuracy: 0.8471 - adl: 0.9543 - fall: 0.7641 - lying_down: 0.7964 - val_loss: 2.4107 - val_categorical_accuracy: 0.4335 - val_adl: 0.1329 - val_fall: 0.5117 - val_lying_down: 0.6438
# Epoch 44/50
# 255/255 [==============================] - 181s 707ms/step - loss: 0.3959 - categorical_accuracy: 0.8292 - adl: 0.9499 - fall: 0.7381 - lying_down: 0.7753 - val_loss: 2.4138 - val_categorical_accuracy: 0.4236 - val_adl: 0.1243 - val_fall: 0.6462 - val_lying_down: 0.4688
# Epoch 45/50
# 255/255 [==============================] - 181s 709ms/step - loss: 0.3764 - categorical_accuracy: 0.8417 - adl: 0.9506 - fall: 0.7656 - lying_down: 0.7920 - val_loss: 2.2237 - val_categorical_accuracy: 0.4008 - val_adl: 0.0925 - val_fall: 0.6754 - val_lying_down: 0.4187
# Epoch 46/50
# 255/255 [==============================] - 180s 703ms/step - loss: 0.3327 - categorical_accuracy: 0.8564 - adl: 0.9528 - fall: 0.7841 - lying_down: 0.8189 - val_loss: 2.3008 - val_categorical_accuracy: 0.3462 - val_adl: 0.0983 - val_fall: 0.4064 - val_lying_down: 0.5031
# Epoch 47/50
# 255/255 [==============================] - 182s 711ms/step - loss: 0.3037 - categorical_accuracy: 0.8652 - adl: 0.9639 - fall: 0.8019 - lying_down: 0.8022 - val_loss: 2.4359 - val_categorical_accuracy: 0.3889 - val_adl: 0.1012 - val_fall: 0.4123 - val_lying_down: 0.6687
# Epoch 48/50
# 255/255 [==============================] - 179s 702ms/step - loss: 0.3248 - categorical_accuracy: 0.8578 - adl: 0.9646 - fall: 0.7908 - lying_down: 0.8051 - val_loss: 2.4588 - val_categorical_accuracy: 0.3929 - val_adl: 0.0694 - val_fall: 0.4298 - val_lying_down: 0.6687
# Epoch 49/50
# 255/255 [==============================] - 181s 708ms/step - loss: 0.3510 - categorical_accuracy: 0.8498 - adl: 0.9639 - fall: 0.7589 - lying_down: 0.8138 - val_loss: 2.0932 - val_categorical_accuracy: 0.4028 - val_adl: 0.1590 - val_fall: 0.5702 - val_lying_down: 0.4344
# Epoch 50/50
# 255/255 [==============================] - 180s 707ms/step - loss: 0.3143 - categorical_accuracy: 0.8637 - adl: 0.9639 - fall: 0.7878 - lying_down: 0.8262 - val_loss: 2.3328 - val_categorical_accuracy: 0.3899 - val_adl: 0.1647 - val_fall: 0.5965 - val_lying_down: 0.3656

# %%
model.save(f"{MED_FALL}/vision/models/3DCNN+ConvLSTM2D_balanced.h5")

# %%
model = tf.keras.models.load_model(f"{MED_FALL}/vision/models/3DCNN+ConvLSTM2D.h5")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 model = tf.keras.models.load_model(f"{MED_FALL}/vision/models/3DCNN+ConvLSTM2D.h5")
#
# File /opt/conda/lib/python3.9/site-packages/keras/saving/save.py:205, in load_model(filepath, custom_objects, compile, options)
#     203       filepath = path_to_string(filepath)
#     204       if isinstance(filepath, str):
# --> 205         return saved_model_load.load(filepath, compile, options)
#     207 raise IOError(
#     208     'Unable to load model. Filepath is not an hdf5 file (or h5py is not '
#     209     'available) or SavedModel.')
#
# File /opt/conda/lib/python3.9/site-packages/keras/saving/saved_model/load.py:108, in load(path, compile, options)
#     103 # TODO(kathywu): Add saving/loading of optimizer, compiled losses and metrics.
#     104 # TODO(kathywu): Add code to load from objects that contain all endpoints
#     105
#     106 # Look for metadata file or parse the SavedModel
#     107 metadata = saved_metadata_pb2.SavedMetadata()
# --> 108 meta_graph_def = tf.__internal__.saved_model.parse_saved_model(path).meta_graphs[0]
#     109 object_graph_def = meta_graph_def.object_graph_def
#     110 path_to_metadata_pb = os.path.join(path, constants.SAVED_METADATA_PATH)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/saved_model/loader_impl.py:118, in parse_saved_model(export_dir)
#     116     raise IOError("Cannot parse file %s: %s." % (path_to_pbtxt, str(e)))
#     117 else:
# --> 118   raise IOError(
#     119       "SavedModel file does not exist at: %s%s{%s|%s}" %
#     120       (export_dir, os.path.sep, constants.SAVED_MODEL_FILENAME_PBTXT,
#     121        constants.SAVED_MODEL_FILENAME_PB))
#
# OSError: SavedModel file does not exist at: /home/jovyan/work/MED_Fall/vision/models/3DCNN+ConvLSTM2D.h5/{saved_model.pbtxt|saved_model.pb}

# %%
model.fit(train_gen, validation_data=val_gen, epochs=50, callbacks=callbacks)

# %%
model = tf.keras.models.load_model(f"{MED_FALL}/vision/models/3DCNN+ConvLSTM2D.h5")

# %%
# plot the accuracies
plt.figure()
plt.plot(history.history["categorical_accuracy"])
plt.plot(history.history["val_categorical_accuracy"])
plt.title("model accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.grid()
plt.show()

# %%
# plot the losses
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.grid()
plt.show()

# %%
y_logits = model.predict(val_gen)
print(y_logits.shape)

# %%
y_preds_encoded = []
for logit in y_logits:
    one_hot_labl = [0, 0, 0]
    argmax = np.argmax(logit, axis=0)
    one_hot_labl[argmax] = 1
    y_preds_encoded.append(one_hot_labl)

y_preds_encoded

# %%
len(val_gen.windows_labels)

# %%
y_true = val_gen.windows_labels[0:2448]
pd.Series(y_true).value_counts()

# %%
y_true_encoded = le.transform(y_true)

# %%
print(
    classification_report(
        y_true=y_true_encoded,
        y_pred=y_preds_encoded,
        target_names=["adl", "fall", "lie_down"],
    ),
)

# %%
model.evaluate(train_gen)

# %%
model.evaluate(val_gen)
